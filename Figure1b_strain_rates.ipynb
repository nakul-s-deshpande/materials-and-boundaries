# %%
import os
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import numpy.ma as ma

import matplotlib.ticker as ticker

from mpl_toolkits.axes_grid1 import make_axes_locatable #for subplot colorbars
from matplotlib.pyplot import cm


# configure plotting
# %config InlineBackend.rc = {'figure.dpi': 300, 'savefig.dpi': 300, \
                            'figure.figsize': (6, 6 / 1.6), 'font.size': 8, \
                            'figure.facecolor': (1, 1, 1, 0),'font.sans-serif':'Latin Modern Math'}

from matplotlib import rc
plt.rc('text', usetex=True)
plt.rc('font', family='serif')


plt.rc('text', usetex=True)
plt.rc('font', family='serif')

def fmt(x, pos):
    a, b = '{:.2e}'.format(x).split('e')
    b = int(b)
    return r'${} \times 10^{{{}}}$'.format(a, b)


# %matplotlib inline

# %% [markdown]
# # Loading data

# %% [markdown]
# ## Bustelo

# %%
os.chdir(
    '/media/nakul/Seagate Portable Drive/Data/DWS_Creep/DWS_Correlation_Outputs/Materials/Bustelo/02_18_2022/'
)

Bustelo_02_18_2022_A = np.load('02_18_2022_A/Bustelo_02_18_2022_A_strain_rates.npz')
Bustelo_02_18_2022_A_ϵ_mean = Bustelo_02_18_2022_A['data1']
Bustelo_02_18_2022_A_ϵ_var = Bustelo_02_18_2022_A['data2']

Bustelo_02_18_2022_B = np.load('02_18_2022_B/Bustelo_02_18_2022_B_strain_rates.npz')
Bustelo_02_18_2022_B_ϵ_mean = Bustelo_02_18_2022_B['data1']
Bustelo_02_18_2022_B_ϵ_var = Bustelo_02_18_2022_B['data2']

Bustelo_02_18_2022_C = np.load('02_18_2022_C/Bustelo_02_18_2022_C_strain_rates.npz')
Bustelo_02_18_2022_C_ϵ_mean = Bustelo_02_18_2022_C['data1']
Bustelo_02_18_2022_C_ϵ_var = Bustelo_02_18_2022_C['data2']

Bustelo_02_18_2022_D = np.load('02_18_2022_D/Bustelo_02_18_2022_D_strain_rates.npz')
Bustelo_02_18_2022_D_ϵ_mean = Bustelo_02_18_2022_D['data1']
Bustelo_02_18_2022_D_ϵ_var = Bustelo_02_18_2022_D['data2']

Bustelo_02_18_2022_E = np.load('02_18_2022_E/Bustelo_02_18_2022_E_strain_rates.npz')
Bustelo_02_18_2022_E_ϵ_mean = Bustelo_02_18_2022_E['data1']
Bustelo_02_18_2022_E_ϵ_var = Bustelo_02_18_2022_E['data2']

Bustelo_02_18_2022_F = np.load('02_18_2022_F/Bustelo_02_18_2022_F_strain_rates.npz')
Bustelo_02_18_2022_F_ϵ_mean = Bustelo_02_18_2022_F['data1']
Bustelo_02_18_2022_F_ϵ_var = Bustelo_02_18_2022_F['data2']

Bustelo_02_18_2022_G = np.load('02_18_2022_G/Bustelo_02_18_2022_G_strain_rates.npz')
Bustelo_02_18_2022_G_ϵ_mean = Bustelo_02_18_2022_G['data1']
Bustelo_02_18_2022_G_ϵ_var = Bustelo_02_18_2022_G['data2']

Bustelo_02_18_2022_H = np.load('02_18_2022_H/Bustelo_02_18_2022_H_strain_rates.npz')
Bustelo_02_18_2022_H_ϵ_mean = Bustelo_02_18_2022_H['data1']
Bustelo_02_18_2022_H_ϵ_var = Bustelo_02_18_2022_H['data2']

Bustelo_02_18_2022_I = np.load('02_18_2022_I/Bustelo_02_18_2022_I_strain_rates.npz')
Flour_02_22_2022_F = np.load('02_22_2022_F/Flour_02_22_2022_F_strain_rates.npz')
Flour_02_22_2022_F_ϵ_mean = Flour_02_22_2022_F['data1']
Flour_02_22_2022_F_ϵ_var = Flour_02_22_2022_F['data2']

Flour_02_22_2022_G = np.load('02_22_2022_G/Flour_02_22_2022_G_strain_rates.npz')
Flour_02_22_2022_G_ϵ_mean = Flour_02_22_2022_G['data1']
Flour_02_22_2022_G_ϵ_var = Flour_02_22_2022_G['data2']

Flour_02_22_2022_H = np.load('02_22_2022_H/Flour_02_22_2022_H_strain_rates.npz')
Flour_02_22_2022_H_ϵ_mean = Flour_02_22_2022_H['data1']
Flour_02_22_2022_H_ϵ_var = Flour_02_22_2022_H['data2']

Flour_02_22_2022_I = np.load('02_22_2022_I/Flour_02_22_2022_I_strain_rates.npz')
Flour_02_22_2022_I_ϵ_mean = Flour_02_22_2022_I['data1']
Flour_02_22_2022_I_ϵ_var = Flour_02_22_2022_I['data2']

Flour_02_22_2022_J = np.load('02_22_2022_J/Flour_02_22_2022_J_strain_rates.npz')
Flour_02_22_2022_J_ϵ_mean = Flour_02_22_2022_J['data1']
Flour_02_22_2022_J_ϵ_var = Flour_02_22_2022_J['data2']

Flour_02_22_2022_ϵ_means = [Flour_02_22_2022_A_ϵ_mean,
                              Flour_02_22_2022_B_ϵ_mean,
                              Flour_02_22_2022_C_ϵ_mean,
                              Flour_02_22_2022_D_ϵ_mean,
                              Flour_02_22_2022_E_ϵ_mean,
                              Flour_02_22_2022_F_ϵ_mean,
                              Flour_02_22_2022_G_ϵ_mean,
                              Flour_02_22_2022_H_ϵ_mean,
                              Flour_02_22_2022_I_ϵ_mean,
                              Flour_02_22_2022_J_ϵ_mean
                             ]

# %% [markdown]
# ## Glass Beads

# %%
os.chdir(
    '/media/nakul/Seagate Portable Drive/Data/DWS_Creep/DWS_Correlation_Outputs/Materials/GlassBeads/02_15_2022/'
)

GlassBeads_02_15_2022_A = np.load('02_15_2022_A/GlassBeads_02_15_2022_A_strain_rates.npz')
GlassBeads_02_15_2022_A_ϵ_mean = GlassBeads_02_15_2022_A['data1']
GlassBeads_02_15_2022_A_ϵ_var = GlassBeads_02_15_2022_A['data2']

GlassBeads_02_15_2022_B = np.load('02_15_2022_B/GlassBeads_02_15_2022_B_strain_rates.npz')
GlassBeads_02_15_2022_B_ϵ_mean = GlassBeads_02_15_2022_B['data1']
GlassBeads_02_15_2022_B_ϵ_var = GlassBeads_02_15_2022_B['data2']

GlassBeads_02_15_2022_C = np.load('02_15_2022_C/GlassBeads_02_15_2022_C_strain_rates.npz')
GlassBeads_02_15_2022_C_ϵ_mean = GlassBeads_02_15_2022_C['data1']
GlassBeads_02_15_2022_C_ϵ_var = GlassBeads_02_15_2022_C['data2']

GlassBeads_02_15_2022_D = np.load('02_15_2022_D/GlassBeads_02_15_2022_D_strain_rates.npz')
GlassBeads_02_15_2022_D_ϵ_mean = GlassBeads_02_15_2022_D['data1']
GlassBeads_02_15_2022_D_ϵ_var = GlassBeads_02_15_2022_D['data2']

GlassBeads_02_15_2022_E = np.load('02_15_2022_E/GlassBeads_02_15_2022_E_strain_rates.npz')
GlassBeads_02_15_2022_E_ϵ_mean = GlassBeads_02_15_2022_E['data1']
GlassBeads_02_15_2022_E_ϵ_var = GlassBeads_02_15_2022_E['data2']

GlassBeads_02_15_2022_F = np.load('02_15_2022_F/GlassBeads_02_15_2022_F_strain_rates.npz')
GlassBeads_02_15_2022_F_ϵ_mean = GlassBeads_02_15_2022_F['data1']
GlassBeads_02_15_2022_F_ϵ_var = GlassBeads_02_15_2022_F['data2']

GlassBeads_02_15_2022_G = np.load('02_15_2022_G/GlassBeads_02_15_2022_G_strain_rates.npz')
GlassBeads_02_15_2022_G_ϵ_mean = GlassBeads_02_15_2022_G['data1']
GlassBeads_02_15_2022_G_ϵ_var = GlassBeads_02_15_2022_G['data2']

GlassBeads_02_15_2022_H = np.load('02_15_2022_H/GlassBeads_02_15_2022_H_strain_rates.npz')
GlassBeads_02_15_2022_H_ϵ_mean = GlassBeads_02_15_2022_H['data1']
GlassBeads_02_15_2022_H_ϵ_var = GlassBeads_02_15_2022_H['data2']

GlassBeads_02_15_2022_I = np.load('02_15_2022_I/GlassBeads_02_15_2022_I_strain_rates.npz')
GlassBeads_02_15_2022_I_ϵ_mean = GlassBeads_02_15_2022_I['data1']
GlassBeads_02_15_2022_I_ϵ_var = GlassBeads_02_15_2022_I['data2']

GlassBeads_02_15_2022_J = np.load('02_15_2022_J/GlassBeads_02_15_2022_J_strain_rates.npz')
GlassBeads_02_15_2022_J_ϵ_mean = GlassBeads_02_15_2022_J['data1']
GlassBeads_02_15_2022_J_ϵ_var = GlassBeads_02_15_2022_J['data2']

GlassBeads_02_15_2022_ϵ_means = [GlassBeads_02_15_2022_A_ϵ_mean,
                              GlassBeads_02_15_2022_B_ϵ_mean,
                              GlassBeads_02_15_2022_C_ϵ_mean,
                              GlassBeads_02_15_2022_D_ϵ_mean,
                              GlassBeads_02_15_2022_E_ϵ_mean,
                              GlassBeads_02_15_2022_F_ϵ_mean,
                              GlassBeads_02_15_2022_G_ϵ_mean,
                              GlassBeads_02_15_2022_H_ϵ_mean,
                              GlassBeads_02_15_2022_I_ϵ_mean,
                              GlassBeads_02_15_2022_J_ϵ_mean
                             ]

# %% [markdown]
# ## Glitter

# %%
os.chdir(
    '/media/nakul/Seagate Portable Drive/Data/DWS_Creep/DWS_Correlation_Outputs/Materials/Glitter/02_18_2022/'
)

Glitter_02_18_2022_A = np.load('02_18_2022_A/Glitter_02_18_2022_A_strain_rates.npz')
Glitter_02_18_2022_A_ϵ_mean = Glitter_02_18_2022_A['data1']
Glitter_02_18_2022_A_ϵ_var = Glitter_02_18_2022_A['data2']

Glitter_02_18_2022_B = np.load('02_18_2022_B/Glitter_02_18_2022_B_strain_rates.npz')
Glitter_02_18_2022_B_ϵ_mean = Glitter_02_18_2022_B['data1']
Glitter_02_18_2022_B_ϵ_var = Glitter_02_18_2022_B['data2']

Glitter_02_18_2022_C = np.load('02_18_2022_C/Glitter_02_18_2022_C_strain_rates.npz')
Glitter_02_18_2022_C_ϵ_mean = Glitter_02_18_2022_C['data1']
Glitter_02_18_2022_C_ϵ_var = Glitter_02_18_2022_C['data2']

Glitter_02_18_2022_D = np.load('02_18_2022_D/Glitter_02_18_2022_D_strain_rates.npz')
Glitter_02_18_2022_D_ϵ_mean = Glitter_02_18_2022_D['data1']
Glitter_02_18_2022_D_ϵ_var = Glitter_02_18_2022_D['data2']

Glitter_02_18_2022_E = np.load('02_18_2022_E/Glitter_02_18_2022_E_strain_rates.npz')
Glitter_02_18_2022_E_ϵ_mean = Glitter_02_18_2022_E['data1']
Glitter_02_18_2022_E_ϵ_var = Glitter_02_18_2022_E['data2']

Glitter_02_18_2022_F = np.load('02_18_2022_F/Glitter_02_18_2022_F_strain_rates.npz')
Glitter_02_18_2022_F_ϵ_mean = Glitter_02_18_2022_F['data1']
Glitter_02_18_2022_F_ϵ_var = Glitter_02_18_2022_F['data2']

Glitter_02_18_2022_G = np.load('02_18_2022_G/Glitter_02_18_2022_G_strain_rates.npz')
Glitter_02_18_2022_G_ϵ_mean = Glitter_02_18_2022_G['data1']
Glitter_02_18_2022_G_ϵ_var = Glitter_02_18_2022_G['data2']

Glitter_02_18_2022_H = np.load('02_18_2022_H/Glitter_02_18_2022_H_strain_rates.npz')
Glitter_02_18_2022_H_ϵ_mean = Glitter_02_18_2022_H['data1']
Glitter_02_18_2022_H_ϵ_var = Glitter_02_18_2022_H['data2']

Glitter_02_18_2022_I = np.load('02_18_2022_I/Glitter_02_18_2022_I_strain_rates.npz')
Glitter_02_18_2022_I_ϵ_mean = Glitter_02_18_2022_I['data1']
Glitter_02_18_2022_I_ϵ_var = Glitter_02_18_2022_I['data2']

Glitter_02_18_2022_J = np.load('02_18_2022_J/Glitter_02_18_2022_J_strain_rates.npz')
Glitter_02_18_2022_J_ϵ_mean = Glitter_02_18_2022_J['data1']
Glitter_02_18_2022_J_ϵ_var = Glitter_02_18_2022_J['data2']

Glitter_02_18_2022_ϵ_means = [Glitter_02_18_2022_A_ϵ_mean,
                              Glitter_02_18_2022_B_ϵ_mean,
                              Glitter_02_18_2022_C_ϵ_mean,
                              Glitter_02_18_2022_D_ϵ_mean,
                              Glitter_02_18_2022_E_ϵ_mean,
                              Glitter_02_18_2022_F_ϵ_mean,
                              Glitter_02_18_2022_G_ϵ_mean,
                              Glitter_02_18_2022_H_ϵ_mean,
                              Glitter_02_18_2022_I_ϵ_mean,
                              Glitter_02_18_2022_J_ϵ_mean
                             ]

# %% [markdown]
# ## Kaolinite

# %%
os.chdir(
    '/media/nakul/Seagate Portable Drive/Data/DWS_Creep/DWS_Correlation_Outputs/Materials/Kaolinite/02_16_2022/'
)

Kaolinite_02_16_2022_A = np.load('02_16_2022_A/Kaolinite_02_16_2022_A_strain_rates.npz')
Kaolinite_02_16_2022_A_ϵ_mean = Kaolinite_02_16_2022_A['data1']
Kaolinite_02_16_2022_A_ϵ_var = Kaolinite_02_16_2022_A['data2']

Kaolinite_02_16_2022_B = np.load('02_16_2022_B/Kaolinite_02_16_2022_B_strain_rates.npz')
Kaolinite_02_16_2022_B_ϵ_mean = Kaolinite_02_16_2022_B['data1']
Kaolinite_02_16_2022_B_ϵ_var = Kaolinite_02_16_2022_B['data2']

Kaolinite_02_16_2022_C = np.load('02_16_2022_C/Kaolinite_02_16_2022_C_strain_rates.npz')
Kaolinite_02_16_2022_C_ϵ_mean = Kaolinite_02_16_2022_C['data1']
Kaolinite_02_16_2022_C_ϵ_var = Kaolinite_02_16_2022_C['data2']

Kaolinite_02_16_2022_D = np.load('02_16_2022_D/Kaolinite_02_16_2022_D_strain_rates.npz')
Kaolinite_02_16_2022_D_ϵ_mean = Kaolinite_02_16_2022_D['data1']
Kaolinite_02_16_2022_D_ϵ_var = Kaolinite_02_16_2022_D['data2']

Kaolinite_02_16_2022_E = np.load('02_16_2022_E/Kaolinite_02_16_2022_E_strain_rates.npz')
Kaolinite_02_16_2022_E_ϵ_mean = Kaolinite_02_16_2022_E['data1']
Kaolinite_02_16_2022_E_ϵ_var = Kaolinite_02_16_2022_E['data2']

Kaolinite_02_16_2022_F = np.load('02_16_2022_F/Kaolinite_02_16_2022_F_strain_rates.npz')
Kaolinite_02_16_2022_F_ϵ_mean = Kaolinite_02_16_2022_F['data1']
Kaolinite_02_16_2022_F_ϵ_var = Kaolinite_02_16_2022_F['data2']

Kaolinite_02_16_2022_G = np.load('02_16_2022_G/Kaolinite_02_16_2022_G_strain_rates.npz')
Kaolinite_02_16_2022_G_ϵ_mean = Kaolinite_02_16_2022_G['data1']
Kaolinite_02_16_2022_G_ϵ_var = Kaolinite_02_16_2022_G['data2']

Kaolinite_02_16_2022_H = np.load('02_16_2022_H/Kaolinite_02_16_2022_H_strain_rates.npz')
Kaolinite_02_16_2022_H_ϵ_mean = Kaolinite_02_16_2022_H['data1']
Kaolinite_02_16_2022_H_ϵ_var = Kaolinite_02_16_2022_H['data2']

Kaolinite_02_16_2022_I = np.load('02_16_2022_I/Kaolinite_02_16_2022_I_strain_rates.npz')
Kaolinite_02_16_2022_I_ϵ_mean = Kaolinite_02_16_2022_I['data1']
Kaolinite_02_16_2022_I_ϵ_var = Kaolinite_02_16_2022_I['data2']

Kaolinite_02_16_2022_J = np.load('02_16_2022_J/Kaolinite_02_16_2022_J_strain_rates.npz')
Kaolinite_02_16_2022_J_ϵ_mean = Kaolinite_02_16_2022_J['data1']
Kaolinite_02_16_2022_J_ϵ_var = Kaolinite_02_16_2022_J['data2']

Kaolinite_02_16_2022_ϵ_means = [Kaolinite_02_16_2022_A_ϵ_mean,
                              Kaolinite_02_16_2022_B_ϵ_mean,
                              Kaolinite_02_16_2022_C_ϵ_mean,
                              Kaolinite_02_16_2022_D_ϵ_mean,
                              Kaolinite_02_16_2022_E_ϵ_mean,
                              Kaolinite_02_16_2022_F_ϵ_mean,
                              Kaolinite_02_16_2022_G_ϵ_mean,
                              Kaolinite_02_16_2022_H_ϵ_mean,
                              Kaolinite_02_16_2022_I_ϵ_mean,
                              Kaolinite_02_16_2022_J_ϵ_mean
                             ]

# %% [markdown]
# ## Pepper

# %%
os.chdir(
    '/media/nakul/Seagate Portable Drive/Data/DWS_Creep/DWS_Correlation_Outputs/Materials/Pepper/02_22_2022/'
)

Pepper_02_22_2022_A = np.load('02_22_2022_A/Pepper_02_22_2022_A_strain_rates.npz')
Pepper_02_22_2022_A_ϵ_mean = Pepper_02_22_2022_A['data1']
Pepper_02_22_2022_A_ϵ_var = Pepper_02_22_2022_A['data2']

Pepper_02_22_2022_B = np.load('02_22_2022_B/Pepper_02_22_2022_B_strain_rates.npz')
Pepper_02_22_2022_B_ϵ_mean = Pepper_02_22_2022_B['data1']
Pepper_02_22_2022_B_ϵ_var = Pepper_02_22_2022_B['data2']

Pepper_02_22_2022_C = np.load('02_22_2022_C/Pepper_02_22_2022_C_strain_rates.npz')
Pepper_02_22_2022_C_ϵ_mean = Pepper_02_22_2022_C['data1']
Pepper_02_22_2022_C_ϵ_var = Pepper_02_22_2022_C['data2']

Pepper_02_22_2022_D = np.load('02_22_2022_D/Pepper_02_22_2022_D_strain_rates.npz')
Pepper_02_22_2022_D_ϵ_mean = Pepper_02_22_2022_D['data1']
Pepper_02_22_2022_D_ϵ_var = Pepper_02_22_2022_D['data2']

Pepper_02_22_2022_E = np.load('02_22_2022_E/Pepper_02_22_2022_E_strain_rates.npz')
Pepper_02_22_2022_E_ϵ_mean = Pepper_02_22_2022_E['data1']
Pepper_02_22_2022_E_ϵ_var = Pepper_02_22_2022_E['data2']

Pepper_02_22_2022_F = np.load('02_22_2022_F/Pepper_02_22_2022_F_strain_rates.npz')
Pepper_02_22_2022_F_ϵ_mean = Pepper_02_22_2022_F['data1']
Pepper_02_22_2022_F_ϵ_var = Pepper_02_22_2022_F['data2']

Pepper_02_22_2022_G = np.load('02_22_2022_G/Pepper_02_22_2022_G_strain_rates.npz')
Pepper_02_22_2022_G_ϵ_mean = Pepper_02_22_2022_G['data1']
Pepper_02_22_2022_G_ϵ_var = Pepper_02_22_2022_G['data2']

Pepper_02_22_2022_H = np.load('02_22_2022_H/Pepper_02_22_2022_H_strain_rates.npz')
Pepper_02_22_2022_H_ϵ_mean = Pepper_02_22_2022_H['data1']
Pepper_02_22_2022_H_ϵ_var = Pepper_02_22_2022_H['data2']

Pepper_02_22_2022_I = np.load('02_22_2022_I/Pepper_02_22_2022_I_strain_rates.npz')
Pepper_02_22_2022_I_ϵ_mean = Pepper_02_22_2022_I['data1']
Pepper_02_22_2022_I_ϵ_var = Pepper_02_22_2022_I['data2']

Pepper_02_22_2022_J = np.load('02_22_2022_J/Pepper_02_22_2022_J_strain_rates.npz')
Pepper_02_22_2022_J_ϵ_mean = Pepper_02_22_2022_J['data1']
Pepper_02_22_2022_J_ϵ_var = Pepper_02_22_2022_J['data2']

Pepper_02_22_2022_ϵ_means = [Pepper_02_22_2022_A_ϵ_mean,
                              Pepper_02_22_2022_B_ϵ_mean,
                              Pepper_02_22_2022_C_ϵ_mean,
                              Pepper_02_22_2022_D_ϵ_mean,
                              Pepper_02_22_2022_E_ϵ_mean,
                              Pepper_02_22_2022_F_ϵ_mean,
                              Pepper_02_22_2022_G_ϵ_mean,
                              Pepper_02_22_2022_H_ϵ_mean,
                              Pepper_02_22_2022_I_ϵ_mean,
                              Pepper_02_22_2022_J_ϵ_mean
                             ]

# %% [markdown]
# ## Salt

# %%
os.chdir(
    '/media/nakul/Seagate Portable Drive/Data/DWS_Creep/DWS_Correlation_Outputs/Materials/Salt/02_21_2022/'
)

Salt_02_21_2022_A = np.load('02_21_2022_A/Salt_02_21_2022_A_strain_rates.npz')
Salt_02_21_2022_A_ϵ_mean = Salt_02_21_2022_A['data1']
Salt_02_21_2022_A_ϵ_var = Salt_02_21_2022_A['data2']

Salt_02_21_2022_B = np.load('02_21_2022_B/Salt_02_21_2022_B_strain_rates.npz')
Salt_02_21_2022_B_ϵ_mean = Salt_02_21_2022_B['data1']
Salt_02_21_2022_B_ϵ_var = Salt_02_21_2022_B['data2']

Salt_02_21_2022_C = np.load('02_21_2022_C/Salt_02_21_2022_C_strain_rates.npz')
Salt_02_21_2022_C_ϵ_mean = Salt_02_21_2022_C['data1']
Salt_02_21_2022_C_ϵ_var = Salt_02_21_2022_C['data2']

Salt_02_21_2022_D = np.load('02_21_2022_D/Salt_02_21_2022_D_strain_rates.npz')
Salt_02_21_2022_D_ϵ_mean = Salt_02_21_2022_D['data1']
Salt_02_21_2022_D_ϵ_var = Salt_02_21_2022_D['data2']

Salt_02_21_2022_E = np.load('02_21_2022_E/Salt_02_21_2022_E_strain_rates.npz')
Salt_02_21_2022_E_ϵ_mean = Salt_02_21_2022_E['data1']
Salt_02_21_2022_E_ϵ_var = Salt_02_21_2022_E['data2']

Salt_02_21_2022_F = np.load('02_21_2022_F/Salt_02_21_2022_F_strain_rates.npz')
Salt_02_21_2022_F_ϵ_mean = Salt_02_21_2022_F['data1']
Salt_02_21_2022_F_ϵ_var = Salt_02_21_2022_F['data2']

Salt_02_21_2022_G = np.load('02_21_2022_G/Salt_02_21_2022_G_strain_rates.npz')
Salt_02_21_2022_G_ϵ_mean = Salt_02_21_2022_G['data1']
Salt_02_21_2022_G_ϵ_var = Salt_02_21_2022_G['data2']

Salt_02_21_2022_H = np.load('02_21_2022_H/Salt_02_21_2022_H_strain_rates.npz')
Salt_02_21_2022_H_ϵ_mean = Salt_02_21_2022_H['data1']
Salt_02_21_2022_H_ϵ_var = Salt_02_21_2022_H['data2']

Salt_02_21_2022_I = np.load('02_21_2022_I/Salt_02_21_2022_I_strain_rates.npz')
Salt_02_21_2022_I_ϵ_mean = Salt_02_21_2022_I['data1']
Salt_02_21_2022_I_ϵ_var = Salt_02_21_2022_I['data2']

Salt_02_21_2022_J = np.load('02_21_2022_J/Salt_02_21_2022_J_strain_rates.npz')
Salt_02_21_2022_J_ϵ_mean = Salt_02_21_2022_J['data1']
Salt_02_21_2022_J_ϵ_var = Salt_02_21_2022_J['data2']

Salt_02_21_2022_ϵ_means = [Salt_02_21_2022_A_ϵ_mean,
                              Salt_02_21_2022_B_ϵ_mean,
                              Salt_02_21_2022_C_ϵ_mean,
                              Salt_02_21_2022_D_ϵ_mean,
                              Salt_02_21_2022_E_ϵ_mean,
                              Salt_02_21_2022_F_ϵ_mean,
                              Salt_02_21_2022_G_ϵ_mean,
                              Salt_02_21_2022_H_ϵ_mean,
                              Salt_02_21_2022_I_ϵ_mean,
                              Salt_02_21_2022_J_ϵ_mean
                             ]

# %% [markdown]
# ## Sugar

# %%
os.chdir(
    '/media/nakul/Seagate Portable Drive/Data/DWS_Creep/DWS_Correlation_Outputs/Materials/Sugar/02_28_2022/'
)

Sugar_02_28_2022_A = np.load('02_28_2022_A/Sugar_02_28_2022_A_strain_rates.npz')
Sugar_02_28_2022_A_ϵ_mean = Sugar_02_28_2022_A['data1']
Sugar_02_28_2022_A_ϵ_var = Sugar_02_28_2022_A['data2']

Sugar_02_28_2022_B = np.load('02_28_2022_B/Sugar_02_28_2022_B_strain_rates.npz')
Sugar_02_28_2022_B_ϵ_mean = Sugar_02_28_2022_B['data1']
Sugar_02_28_2022_B_ϵ_var = Sugar_02_28_2022_B['data2']

Sugar_02_28_2022_C = np.load('02_28_2022_C/Sugar_02_28_2022_C_strain_rates.npz')
Sugar_02_28_2022_C_ϵ_mean = Sugar_02_28_2022_C['data1']
Sugar_02_28_2022_C_ϵ_var = Sugar_02_28_2022_C['data2']

Sugar_02_28_2022_D = np.load('02_28_2022_D/Sugar_02_28_2022_D_strain_rates.npz')
Sugar_02_28_2022_D_ϵ_mean = Sugar_02_28_2022_D['data1']
Sugar_02_28_2022_D_ϵ_var = Sugar_02_28_2022_D['data2']

Sugar_02_28_2022_E = np.load('02_28_2022_E/Sugar_02_28_2022_E_strain_rates.npz')
Sugar_02_28_2022_E_ϵ_mean = Sugar_02_28_2022_E['data1']
Sugar_02_28_2022_E_ϵ_var = Sugar_02_28_2022_E['data2']

Sugar_02_28_2022_F = np.load('02_28_2022_F/Sugar_02_28_2022_F_strain_rates.npz')
Sugar_02_28_2022_F_ϵ_mean = Sugar_02_28_2022_F['data1']
Sugar_02_28_2022_F_ϵ_var = Sugar_02_28_2022_F['data2']

Sugar_02_28_2022_G = np.load('02_28_2022_G/Sugar_02_28_2022_G_strain_rates.npz')
Sugar_02_28_2022_G_ϵ_mean = Sugar_02_28_2022_G['data1']
Sugar_02_28_2022_G_ϵ_var = Sugar_02_28_2022_G['data2']

Sugar_02_28_2022_H = np.load('02_28_2022_H/Sugar_02_28_2022_H_strain_rates.npz')
Sugar_02_28_2022_H_ϵ_mean = Sugar_02_28_2022_H['data1']
Sugar_02_28_2022_H_ϵ_var = Sugar_02_28_2022_H['data2']

Sugar_02_28_2022_I = np.load('02_28_2022_I/Sugar_02_28_2022_I_strain_rates.npz')
Sugar_02_28_2022_I_ϵ_mean = Sugar_02_28_2022_I['data1']
Sugar_02_28_2022_I_ϵ_var = Sugar_02_28_2022_I['data2']

Sugar_02_28_2022_J = np.load('02_28_2022_J/Sugar_02_28_2022_J_strain_rates.npz')
Sugar_02_28_2022_J_ϵ_mean = Sugar_02_28_2022_J['data1']
Sugar_02_28_2022_J_ϵ_var = Sugar_02_28_2022_J['data2']

Sugar_02_28_2022_ϵ_means = [Sugar_02_28_2022_A_ϵ_mean,
Yeast_02_25_2022_J = np.load('02_25_2022_J/Yeast_02_25_2022_J_strain_rates.npz')
Yeast_02_25_2022_J_ϵ_mean = Yeast_02_25_2022_J['data1']
Yeast_02_25_2022_J_ϵ_var = Yeast_02_25_2022_J['data2']

Yeast_02_25_2022_ϵ_means = [Yeast_02_25_2022_A_ϵ_mean,
                              Yeast_02_25_2022_B_ϵ_mean,
                              Yeast_02_25_2022_C_ϵ_mean,
                              Yeast_02_25_2022_D_ϵ_mean,
                              Yeast_02_25_2022_E_ϵ_mean,
                              Yeast_02_25_2022_F_ϵ_mean,
                              Yeast_02_25_2022_G_ϵ_mean,
                              Yeast_02_25_2022_H_ϵ_mean,
                              Yeast_02_25_2022_I_ϵ_mean,
                              Yeast_02_25_2022_J_ϵ_mean
                             ]

# %% [markdown]
# # Ensemble

# %%
fig = plt.figure(figsize=(4, 1))


ax1 = plt.subplot(111)

lw = 2

color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax1.plot(Yeast_02_25_2022_ϵ_means[i],linewidth = lw,color = c)
    ax1.set_yscale('log')
#     ax1.set_xticks([])
#     ax1.set_yticks([])

ax1.yaxis.tick_right()
ax1.yaxis.set_label_position("right")
ax1.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
ax1.set_xlabel(r'time $t_w$')



# plt.savefig('/home/nakul/Documents/Python Scripts/MaterialsBoundaries/Materials/Yeast_EnsembleTimeseries.svg', bbox_inches='tight')
# Out:
# Text(0.5, 0, 'time $t_w$')

# %%
experiment_names = np.arange(0,10,1)
experiment_names = list(experiment_names)

# %%
experiment_names = ["a","b","c","d","e","f","g","h","i","j"]

# %%
# dark style sheet plotting

plt.style.use('dark_background')

# %%
fig = plt.figure(figsize=(10, 3))


ax1 = plt.subplot(2,5,1)
ax2 = plt.subplot(2,5,2)
ax3 = plt.subplot(2,5,3)
ax4 = plt.subplot(2,5,4)
ax5 = plt.subplot(2,5,5)
ax6 = plt.subplot(2,5,6)
ax7 = plt.subplot(2,5,7)
ax8 = plt.subplot(2,5,8)
ax9 = plt.subplot(2,5,9)
ax10 = plt.subplot(2,5,10)

time = np.arange(0,100,1)
lw = 2

color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax1.plot(GlassBeads_02_15_2022_ϵ_means[i],linewidth = lw,color = c)
    ax1.set_yscale('log')
    
color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax2.plot(CrushedSilica_02_16_2022_ϵ_means[i],linewidth = lw,color = c)
    ax2.set_yscale('log')

    
color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax3.plot(Glitter_02_18_2022_ϵ_means[i],linewidth = lw,color = c)
    ax3.set_yscale('log')

color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax4.plot(Kaolinite_02_16_2022_ϵ_means[i],linewidth = lw,color = c)
    ax4.set_yscale('log')


color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax5.plot(Bustelo_02_18_2022_ϵ_means[i],linewidth = lw,color = c)
    ax5.set_yscale('log')


    
color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax6.plot(Salt_02_21_2022_ϵ_means[i],linewidth = lw,color = c)
    ax6.set_yscale('log')

    
color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax7.plot(Pepper_02_22_2022_ϵ_means[i],linewidth = lw,color = c)
    ax7.set_yscale('log')
      

color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax8.plot(Flour_02_22_2022_ϵ_means[i],linewidth = lw,color = c)
    ax8.set_yscale('log')

color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax9.plot(Sugar_02_28_2022_ϵ_means[i],linewidth = lw,color = c)
    ax9.set_yscale('log')
  

color = iter(cm.RdYlBu(np.linspace(0, 1, 10)))
for i in range(10):
    c = next(color)
    ax10.plot(time,Yeast_02_25_2022_ϵ_means[i],linewidth = lw,color = c,label = experiment_names[i])
    ax10.set_yscale('log')
  
ax1.set_title("glass beads")
ax2.set_title("crushed silica")
ax3.set_title("glitter")
ax4.set_title("kaolinite")
ax5.set_title("coffee")
ax6.set_title("salt")
ax7.set_title("pepper")
ax8.set_title("flour")
ax9.set_title("sugar")
ax10.set_title("yeast")

ax1.tick_params(labelbottom=False)    
ax2.tick_params(labelbottom=False)   
ax3.tick_params(labelbottom=False)   
ax4.tick_params(labelbottom=False)   
ax5.tick_params(labelbottom=False)   
# ax6.tick_params(labelbottom=False)   
# ax7.tick_params(labelbottom=False)   
# ax8.tick_params(labelbottom=False)   
# ax9.tick_params(labelbottom=False)   

ax1.set_xlim([0,100])
ax2.set_xlim([0,100])
ax3.set_xlim([0,100])
ax4.set_xlim([0,100])
ax5.set_xlim([0,100])
ax6.set_xlim([0,100])
ax7.set_xlim([0,100])
ax8.set_xlim([0,100])
ax9.set_xlim([0,100])
ax10.set_xlim([0,100])

ax1.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
# ax2.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
# ax3.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
# ax4.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
# ax5.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
ax6.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
# ax7.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
# ax8.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
# ax9.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')
# ax10.set_ylabel(r'$ \langle \dot{\epsilon} \rangle$ $[s^{-1}]$')



ax8.set_xlabel(r'time $t_w$ [s]')



# box = ax10.get_position()
# lgd = ax10.legend()
# ax10.set_position([box.x0, box.y0, box.width * 0.8, box.height])
# ax10.legend(title='realization',
#            loc='center left',
#            frameon=False,
#            bbox_to_anchor=(1, .5),
#            title_fontsize=12)


# ax2.set_yticks([0,100])
# ax3.set_xlim([0,100])
# ax4.set_xlim([0,100])
# ax5.set_xlim([0,100])
# ax7.set_xlim([0,100])
# ax8.set_xlim([0,100])
# ax9.set_xlim([0,100])
# ax10.set_xlim([0,100])


plt.tight_layout()
plt.savefig('/home/nakul/Documents/NaturalPhilosophy/Presentations/PhD_Defense/Images/MaterialEnsembleTimeseries.png', bbox_inches='tight')

# %%
for i in range(10):
    
    c = next(color)

    ax = fig.add_subplot(2, 5, idx)
    
    ax.plot(time_cumulative,tau_means[i],'o',color = c,markeredgecolor = 'k',markeredgewidth=0.1,markersize = ms)
    
    ax.set_yscale('log')
    ax.set_xscale('log')
    
    ax.set_xticks([])
    ax.set_yticks([])
    
    ax.set_xlim([1e0,5e3])
    ax.set_ylim([1e2,1e6])

    idx += 1
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_19507/1104695781.py in <module>
#       1 for i in range(10):
#       2
# ----> 3     c = next(color)
#       4
#       5     ax = fig.add_subplot(2, 5, idx)
#
# StopIteration:

# %%
time = np.arange(0,100,1)

fig = plt.figure(figsize=(8, 2))

ax = plt.subplot(111)

ax.plot(time,strain_rate_avg,'k')

ax.fill_between(time,
                strain_rate_avg - strain_rate_var,
                strain_rate_avg + strain_rate_var,
                alpha=.3,
                edgecolor='k')

# ax.set_yscale('log')
